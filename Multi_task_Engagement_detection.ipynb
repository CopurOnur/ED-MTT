# %%
# %load_ext autoreload
# %autoreload 2
#%env PYTHONPATH=.
# %cd /content/drive/MyDrive/Multi-task_Engagement_Detection
# Out:
# /content/drive/MyDrive/Multi-task_Engagement_Detection

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Unzip the Data

# %%
# !unzip data/OpenFace_Features.zip -d /data/OpeFace
# Out:
# unzip:  cannot find or open data/OpenFace_Features.zip, data/OpenFace_Features.zip.zip or data/OpenFace_Features.zip.ZIP.

# %%
# %cd /content/drive/MyDrive/Multi-task_Engagement_Detection
# Out:
# /content/drive/MyDrive/Multi-task_Engagement_Detection

# %%
# !pip install https://github.com/ufoym/imbalanced-dataset-sampler/archive/master.zip
# Out:
# ...
#      - 297 kB 409 kB/s
# ...
#   Created wheel for torchsampler: filename=torchsampler-0.1.1-py3-none-any.whl size=3838 sha256=7c337c38230165796ede82d6903e0e46d6839e347ac8d20bad0a052338bcce24
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xfbycxhy/wheels/52/7b/7d/ce0e0ddbb7864877a0e31a96f883a928791ebfa6eaf7b52f87
# Successfully built torchsampler
# ...

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# wandb: Currently logged in as: onurcopur (use `wandb login --relogin` to force relogin)
# /usr/local/lib/python3.7/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'batchnorm_default': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/hydra/_internal/defaults_list.py:412: UserWarning: In batchnorm_default: Invalid overriding of hydra/job_logging:
# Default list overrides requires 'override' keyword.
# See https://hydra.cc/docs/next/upgrades/1.0_to_1.1/defaults_list_override for more information.
#
#   deprecation_warning(msg)
# ...

# %%
# !wandb sweep configs/sweep.yaml
# Out:
# wandb: Creating sweep from: configs/sweep.yaml
# wandb: Created sweep with ID: 5peyduc9
# wandb: View sweep at: https://wandb.ai/onurcopur/uncategorized/sweeps/5peyduc9
# wandb: Run sweep agent with: wandb agent onurcopur/uncategorized/5peyduc9

# %%
# !wandb agent onurcopur/uncategorized/5peyduc9

# %% [markdown]
# # Inference

# %%
# !python test.py
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# wandb: Currently logged in as: onurcopur (use `wandb login --relogin` to force relogin)
# /usr/local/lib/python3.7/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'batchnorm_default': Defaults list is missing `_self_`. See https://hydra.cc/docs/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/hydra/_internal/defaults_list.py:412: UserWarning: In batchnorm_default: Invalid overriding of hydra/job_logging:
# Default list overrides requires 'override' keyword.
# See https://hydra.cc/docs/next/upgrades/1.0_to_1.1/defaults_list_override for more information.
#
#   deprecation_warning(msg)
# ...

# %%
import numpy as np
import sys
sys.path.insert(1, '/content/drive/MyDrive/Multi-task_Engagement_Detection')
import utils
import seaborn as sns
from pylab import rcParams

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#93D30C", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 16, 10
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
predictions = np.load("predictions.npy")
labels = np.load("labels.npy")

# %%
utils.plot_graph(predictions,labels)
